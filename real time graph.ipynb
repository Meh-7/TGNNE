# %%
from IPython.display import display, clear_output, Image, HTML
import time

imgs = [
    "loss_curve.png",
    "loss_and_MR.png",
    "loss_and_scaled_metrics.png",
]

base = "/workspace/TGNNE/checkpoints/FB15k-237/20260130_145831"

while True:
    clear_output(wait=True)
    display(HTML("<h3>Training Progress</h3>"))
    for img in imgs:
        try:
            display(Image(filename=f"{base}/{img}", width=600))
        except:
            print(f"Waiting for {img}...")
    time.sleep(30)
