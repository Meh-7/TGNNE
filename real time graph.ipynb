# %%
from IPython.display import display, clear_output, Image
import time

img = "/workspace/TGNNE/checkpoints/FB15k-237/20260127_125435/loss_curve.png"

while True:
    clear_output(wait=True)
    try:
        display(Image(filename=img))
    except:
        print("Waiting for plot...")
    time.sleep(30)
